# %%
from IPython.core.display import display
import pandas as pd
import numpy as np
df = pd.read_csv('./date/train.csv',header=0)
dfs = pd.read_csv('./date/test.csv',header=0)

# %%
print(df.shape)
print(df.dtypes)
print(df.isnull().sum())
# Out:
# (207, 12)
# datetime          object
# y                  int64
# week              object
# soldout            int64
# name              object
# kcal             float64
# remarks           object
# event             object
# payday           float64
# weather           object
# precipitation     object
# temperature      float64
# dtype: object
# datetime           0
# y                  0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# dtype: int64

# %%
print(dfs.shape)
print(dfs.dtypes)
print(dfs.isnull().sum())
# Out:
# (40, 11)
# datetime          object
# week              object
# soldout            int64
# name              object
# kcal             float64
# remarks           object
# event             object
# payday           float64
# weather           object
# precipitation     object
# temperature      float64
# dtype: object
# datetime          0
# week              0
# soldout           0
# name              0
# kcal              4
# remarks          33
# event            37
# payday           38
# weather           0
# precipitation     0
# temperature       0
# dtype: int64

# %%
print(pd.get_option('display.max_rows'))
pd.set_option('display.max_rows', 500)
df
# Out:
# 500
#        datetime    y week  soldout              name   kcal  \
# 0    2013-11-18   90    月        0          厚切りイカフライ    NaN
# 1    2013-11-19  101    火        1           手作りヒレカツ    NaN
# 2    2013-11-20  118    水        0        白身魚唐揚げ野菜あん    NaN
# 3    2013-11-21  120    木        1            若鶏ピリ辛焼    NaN
# 4    2013-11-22  130    金        1          ビッグメンチカツ    NaN
# 5    2013-11-25  135    月        1              鶏の唐揚    NaN
# 6    2013-11-26  145    火        0          豚のスタミナ炒め    NaN
# 7    2013-11-27  140    水        1          ボローニャ風カツ    NaN
# 8    2013-11-28  151    木        0             ハンバーグ    NaN
# 9    2013-11-29  116    金        0     タルタルinソーセージカツ    NaN
# 10    2013-12-2  151    月        1             マーボ豆腐    NaN
# 11    2013-12-3  153    火        1          厚揚げ豚生姜炒め    NaN
# 12    2013-12-4  151    水        1      クリームチーズ入りメンチ    NaN
# 13    2013-12-5  171    木        0       鶏のカッシュナッツ炒め    NaN
# ...

# %%
print(pd.get_option('display.max_rows'))
pd.set_option('display.max_rows', 500)
dfs
# Out:
# 500
#       datetime week  soldout            name   kcal         remarks  \
# 0    2014-10-1    水        1           メンチカツ  420.0             NaN
# 1    2014-10-2    木        0       バーベキューチキン  415.0             NaN
# 2    2014-10-3    金        0      豚肉のマスタード焼き  405.0             NaN
# 3    2014-10-6    月        1            麻婆春雨  400.0             NaN
# 4    2014-10-7    火        0        厚揚げ肉みそ炒め  430.0             NaN
# 5    2014-10-8    水        0    完熟トマトのホットカレー  420.0             NaN
# 6    2014-10-9    木        0          豚キムチ炒め  435.0             NaN
# 7   2014-10-10    金        0          ポークカレー    NaN        お楽しみメニュー
# 8   2014-10-14    火        0         若鶏梅肉包揚げ  408.0             NaN
# 9   2014-10-15    水        1         ミックスグリル  450.0    料理長のこだわりメニュー
# 10  2014-10-16    木        0      豚肉と白菜の中華炒め  400.0             NaN
# 11  2014-10-17    金        0            ヒレカツ  415.0             NaN
# 12  2014-10-20    月        1             豚柳川  426.0             NaN
# ...

# %%
df = pd.read_csv('./date/train.csv',index_col=['datetime'],header=0)
dfs = pd.read_csv('./date/test.csv',index_col=['datetime'],header=0)

# %%
df['payday'] = df['payday'].fillna(0)
df['precipitation'] = df['precipitation'].replace('--', '0')

dfs['payday'] = dfs['payday'].fillna(0)
dfs['precipitation'] = dfs['precipitation'].replace('--', '0')

df = df.astype({'soldout': 'object', 'payday': 'object'})
dfs = dfs.astype({'soldout': 'object', 'payday': 'object'})

# %%
df['days'] = range(1,len(df)+1)
df
# Out:
#               y week soldout              name   kcal  \
# datetime
# 2013-11-18   90    月       0          厚切りイカフライ    NaN
# 2013-11-19  101    火       1           手作りヒレカツ    NaN
# 2013-11-20  118    水       0        白身魚唐揚げ野菜あん    NaN
# 2013-11-21  120    木       1            若鶏ピリ辛焼    NaN
# 2013-11-22  130    金       1          ビッグメンチカツ    NaN
# 2013-11-25  135    月       1              鶏の唐揚    NaN
# 2013-11-26  145    火       0          豚のスタミナ炒め    NaN
# 2013-11-27  140    水       1          ボローニャ風カツ    NaN
# 2013-11-28  151    木       0             ハンバーグ    NaN
# 2013-11-29  116    金       0     タルタルinソーセージカツ    NaN
# 2013-12-2   151    月       1             マーボ豆腐    NaN
# 2013-12-3   153    火       1          厚揚げ豚生姜炒め    NaN
# 2013-12-4   151    水       1      クリームチーズ入りメンチ    NaN
# 2013-12-5   171    木       0       鶏のカッシュナッツ炒め    NaN
# 2013-12-6   134    金       0          手作りロースカツ    NaN
# 2013-12-9   165    月       1        ハンバーグデミソース    NaN
# ...

# %%
dfs['days'] = range(207,len(dfs)+1)
dfs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0912b868c867> in <module>
# ----> 1 dfs['days'] = range(207,len(dfs)+1)
#       2 dfs
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# ...
